# %%
# !pip install pyedflib
# Out:
# Collecting pyedflib
#   Downloading https://files.pythonhosted.org/packages/a4/c1/11d90aa4d20a1d3df04ea9e1db4e03fea4b199a5b515a057cbe5e35769c0/pyEDFlib-0.1.14.tar.gz (1.1MB)
#      |████████████████████████████████| 1.1MB 2.8MB/s
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.6/dist-packages (from pyedflib) (1.16.3)
# Building wheels for collected packages: pyedflib
#   Building wheel for pyedflib (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/6a/62/a0/3d06c48411a5f8e18a7d7376243b81520af87cbd6f24d21cfd
# Successfully built pyedflib
# Installing collected packages: pyedflib
# Successfully installed pyedflib-0.1.14

# %%
# !wget -r --no-parent https://physionet.org/pn6/chbmit/
# Out:
# --2019-05-29 15:03:44--  https://physionet.org/pn6/chbmit/
# Resolving physionet.org (physionet.org)... 128.30.30.88
# Connecting to physionet.org (physionet.org)|128.30.30.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/index.html’
#
# physionet.org/pn6/c     [ <=>                ]  25.29K  --.-KB/s    in 0.07s
#
# 2019-05-29 15:03:45 (370 KB/s) - ‘physionet.org/pn6/chbmit/index.html’ saved [25900]
#
# Loading robots.txt; please ignore errors.
# --2019-05-29 15:03:45--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 106 [text/plain]
# Saving to: ‘physionet.org/robots.txt’
#
# physionet.org/robot 100%[===================>]     106  --.-KB/s    in 0s
#
# 2019-05-29 15:03:45 (14.0 MB/s) - ‘physionet.org/robots.txt’ saved [106/106]
#
# --2019-05-29 15:03:45--  https://physionet.org/pn6/chbmit/local.css
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3221 (3.1K) [text/css]
# Saving to: ‘physionet.org/pn6/chbmit/local.css’
#
# physionet.org/pn6/c 100%[===================>]   3.15K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:45 (424 MB/s) - ‘physionet.org/pn6/chbmit/local.css’ saved [3221/3221]
#
# --2019-05-29 15:03:45--  https://physionet.org/pn6/chbmit/SUBJECT-INFO
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 284
# Saving to: ‘physionet.org/pn6/chbmit/SUBJECT-INFO’
#
# physionet.org/pn6/c 100%[===================>]     284  --.-KB/s    in 0s
#
# 2019-05-29 15:03:45 (38.1 MB/s) - ‘physionet.org/pn6/chbmit/SUBJECT-INFO’ saved [284/284]
#
# --2019-05-29 15:03:45--  https://physionet.org/pn6/chbmit/RECORDS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 13056 (13K)
# Saving to: ‘physionet.org/pn6/chbmit/RECORDS’
#
# physionet.org/pn6/c 100%[===================>]  12.75K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:45 (111 MB/s) - ‘physionet.org/pn6/chbmit/RECORDS’ saved [13056/13056]
#
# --2019-05-29 15:03:45--  https://physionet.org/pn6/chbmit/RECORDS-WITH-SEIZURES
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2684 (2.6K)
# Saving to: ‘physionet.org/pn6/chbmit/RECORDS-WITH-SEIZURES’
#
# physionet.org/pn6/c 100%[===================>]   2.62K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:45 (379 MB/s) - ‘physionet.org/pn6/chbmit/RECORDS-WITH-SEIZURES’ saved [2684/2684]
#
# --2019-05-29 15:03:45--  https://physionet.org/pn6/chbmit/shoeb-icml-2010.pdf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1988132 (1.9M) [application/pdf]
# Saving to: ‘physionet.org/pn6/chbmit/shoeb-icml-2010.pdf’
#
# physionet.org/pn6/c 100%[===================>]   1.90M  --.-KB/s    in 0.1s
#
# 2019-05-29 15:03:45 (14.6 MB/s) - ‘physionet.org/pn6/chbmit/shoeb-icml-2010.pdf’ saved [1988132/1988132]
#
# --2019-05-29 15:03:45--  https://physionet.org/pn6/chbmit/?C=N;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/index.html?C=N;O=D’
#
# physionet.org/pn6/c     [ <=>                ]  25.36K  --.-KB/s    in 0.07s
#
# 2019-05-29 15:03:45 (377 KB/s) - ‘physionet.org/pn6/chbmit/index.html?C=N;O=D’ saved [25964]
#
# --2019-05-29 15:03:45--  https://physionet.org/pn6/chbmit/?C=M;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/index.html?C=M;O=A’
#
# physionet.org/pn6/c     [ <=>                ]  25.36K  --.-KB/s    in 0.07s
#
# 2019-05-29 15:03:45 (358 KB/s) - ‘physionet.org/pn6/chbmit/index.html?C=M;O=A’ saved [25964]
#
# --2019-05-29 15:03:45--  https://physionet.org/pn6/chbmit/?C=S;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/index.html?C=S;O=A’
#
# physionet.org/pn6/c     [ <=>                ]  25.36K  --.-KB/s    in 0.07s
#
# 2019-05-29 15:03:46 (366 KB/s) - ‘physionet.org/pn6/chbmit/index.html?C=S;O=A’ saved [25964]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/?C=D;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/index.html?C=D;O=A’
#
# physionet.org/pn6/c     [ <=>                ]  25.36K  --.-KB/s    in 0.07s
#
# 2019-05-29 15:03:46 (363 KB/s) - ‘physionet.org/pn6/chbmit/index.html?C=D;O=A’ saved [25964]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/ANNOTATORS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 43
# Saving to: ‘physionet.org/pn6/chbmit/ANNOTATORS’
#
# physionet.org/pn6/c 100%[===================>]      43  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (5.64 MB/s) - ‘physionet.org/pn6/chbmit/ANNOTATORS’ saved [43/43]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/DOI
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 19
# Saving to: ‘physionet.org/pn6/chbmit/DOI’
#
# physionet.org/pn6/c 100%[===================>]      19  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (2.68 MB/s) - ‘physionet.org/pn6/chbmit/DOI’ saved [19/19]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/MD5SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 390
# Saving to: ‘physionet.org/pn6/chbmit/MD5SUMS’
#
# physionet.org/pn6/c 100%[===================>]     390  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (43.0 MB/s) - ‘physionet.org/pn6/chbmit/MD5SUMS’ saved [390/390]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/SHA1SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 504
# Saving to: ‘physionet.org/pn6/chbmit/SHA1SUMS’
#
# physionet.org/pn6/c 100%[===================>]     504  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (69.2 MB/s) - ‘physionet.org/pn6/chbmit/SHA1SUMS’ saved [504/504]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/SHA256SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 795
# Saving to: ‘physionet.org/pn6/chbmit/SHA256SUMS’
#
# physionet.org/pn6/c 100%[===================>]     795  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (114 MB/s) - ‘physionet.org/pn6/chbmit/SHA256SUMS’ saved [795/795]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb01/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb01/index.html’
#
# physionet.org/pn6/c     [ <=>                ]   8.12K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (74.4 MB/s) - ‘physionet.org/pn6/chbmit/chb01/index.html’ saved [8320]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb02/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6866 (6.7K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb02/index.html’
#
# physionet.org/pn6/c 100%[===================>]   6.71K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (124 MB/s) - ‘physionet.org/pn6/chbmit/chb02/index.html’ saved [6866/6866]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb03/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7752 (7.6K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb03/index.html’
#
# physionet.org/pn6/c 100%[===================>]   7.57K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (145 MB/s) - ‘physionet.org/pn6/chbmit/chb03/index.html’ saved [7752/7752]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb04/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7716 (7.5K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb04/index.html’
#
# physionet.org/pn6/c 100%[===================>]   7.54K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (133 MB/s) - ‘physionet.org/pn6/chbmit/chb04/index.html’ saved [7716/7716]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb05/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7592 (7.4K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb05/index.html’
#
# physionet.org/pn6/c 100%[===================>]   7.41K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (159 MB/s) - ‘physionet.org/pn6/chbmit/chb05/index.html’ saved [7592/7592]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb06/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4912 (4.8K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb06/index.html’
#
# physionet.org/pn6/c 100%[===================>]   4.80K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (58.7 MB/s) - ‘physionet.org/pn6/chbmit/chb06/index.html’ saved [4912/4912]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb07/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4450 (4.3K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb07/index.html’
#
# physionet.org/pn6/c 100%[===================>]   4.35K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (86.4 MB/s) - ‘physionet.org/pn6/chbmit/chb07/index.html’ saved [4450/4450]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb08/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4894 (4.8K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb08/index.html’
#
# physionet.org/pn6/c 100%[===================>]   4.78K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (101 MB/s) - ‘physionet.org/pn6/chbmit/chb08/index.html’ saved [4894/4894]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb09/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4450 (4.3K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb09/index.html’
#
# physionet.org/pn6/c 100%[===================>]   4.35K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (78.1 MB/s) - ‘physionet.org/pn6/chbmit/chb09/index.html’ saved [4450/4450]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb10/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5906 (5.8K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb10/index.html’
#
# physionet.org/pn6/c 100%[===================>]   5.77K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (125 MB/s) - ‘physionet.org/pn6/chbmit/chb10/index.html’ saved [5906/5906]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb11/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6722 (6.6K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb11/index.html’
#
# physionet.org/pn6/c 100%[===================>]   6.56K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (115 MB/s) - ‘physionet.org/pn6/chbmit/chb11/index.html’ saved [6722/6722]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb12/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6670 (6.5K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb12/index.html’
#
# physionet.org/pn6/c 100%[===================>]   6.51K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (144 MB/s) - ‘physionet.org/pn6/chbmit/chb12/index.html’ saved [6670/6670]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb13/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7193 (7.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb13/index.html’
#
# physionet.org/pn6/c 100%[===================>]   7.02K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (78.7 MB/s) - ‘physionet.org/pn6/chbmit/chb13/index.html’ saved [7193/7193]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb14/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6048 (5.9K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb14/index.html’
#
# physionet.org/pn6/c 100%[===================>]   5.91K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (86.0 MB/s) - ‘physionet.org/pn6/chbmit/chb14/index.html’ saved [6048/6048]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb15/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb15/index.html’
#
# physionet.org/pn6/c     [ <=>                ]   8.88K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (84.7 MB/s) - ‘physionet.org/pn6/chbmit/chb15/index.html’ saved [9093]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb16/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4903 (4.8K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb16/index.html’
#
# physionet.org/pn6/c 100%[===================>]   4.79K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (53.0 MB/s) - ‘physionet.org/pn6/chbmit/chb16/index.html’ saved [4903/4903]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb17/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4758 (4.6K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb17/index.html’
#
# physionet.org/pn6/c 100%[===================>]   4.65K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (109 MB/s) - ‘physionet.org/pn6/chbmit/chb17/index.html’ saved [4758/4758]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb18/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7317 (7.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb18/index.html’
#
# physionet.org/pn6/c 100%[===================>]   7.15K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (155 MB/s) - ‘physionet.org/pn6/chbmit/chb18/index.html’ saved [7317/7317]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb19/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6012 (5.9K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb19/index.html’
#
# physionet.org/pn6/c 100%[===================>]   5.87K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (115 MB/s) - ‘physionet.org/pn6/chbmit/chb19/index.html’ saved [6012/6012]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb20/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6323 (6.2K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb20/index.html’
#
# physionet.org/pn6/c 100%[===================>]   6.17K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (107 MB/s) - ‘physionet.org/pn6/chbmit/chb20/index.html’ saved [6323/6323]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb21/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6589 (6.4K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb21/index.html’
#
# physionet.org/pn6/c 100%[===================>]   6.43K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (86.1 MB/s) - ‘physionet.org/pn6/chbmit/chb21/index.html’ saved [6589/6589]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb22/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6154 (6.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb22/index.html’
#
# physionet.org/pn6/c 100%[===================>]   6.01K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (91.6 MB/s) - ‘physionet.org/pn6/chbmit/chb22/index.html’ saved [6154/6154]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb23/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3030 (3.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb23/index.html’
#
# physionet.org/pn6/c 100%[===================>]   2.96K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:46 (384 MB/s) - ‘physionet.org/pn6/chbmit/chb23/index.html’ saved [3030/3030]
#
# --2019-05-29 15:03:46--  https://physionet.org/pn6/chbmit/chb24/
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6235 (6.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb24/index.html’
#
# physionet.org/pn6/c 100%[===================>]   6.09K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:47 (134 MB/s) - ‘physionet.org/pn6/chbmit/chb24/index.html’ saved [6235/6235]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/?C=N;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/index.html?C=N;O=A’
#
# physionet.org/pn6/c     [ <=>                ]  25.36K  --.-KB/s    in 0.07s
#
# 2019-05-29 15:03:47 (389 KB/s) - ‘physionet.org/pn6/chbmit/index.html?C=N;O=A’ saved [25964]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/index.html?C=M;O=D’
#
# physionet.org/pn6/c     [ <=>                ]  25.36K  --.-KB/s    in 0.07s
#
# 2019-05-29 15:03:47 (390 KB/s) - ‘physionet.org/pn6/chbmit/index.html?C=M;O=D’ saved [25964]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/index.html?C=S;O=D’
#
# physionet.org/pn6/c     [ <=>                ]  25.36K  --.-KB/s    in 0.07s
#
# 2019-05-29 15:03:47 (372 KB/s) - ‘physionet.org/pn6/chbmit/index.html?C=S;O=D’ saved [25964]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/index.html?C=D;O=D’
#
# physionet.org/pn6/c     [ <=>                ]  25.36K  --.-KB/s    in 0.07s
#
# 2019-05-29 15:03:47 (382 KB/s) - ‘physionet.org/pn6/chbmit/index.html?C=D;O=D’ saved [25964]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/chb01/?C=N;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb01/index.html?C=N;O=D’
#
# physionet.org/pn6/c     [ <=>                ]   8.12K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:47 (70.9 MB/s) - ‘physionet.org/pn6/chbmit/chb01/index.html?C=N;O=D’ saved [8320]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/chb01/?C=M;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb01/index.html?C=M;O=A’
#
# physionet.org/pn6/c     [ <=>                ]   8.12K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:47 (90.0 MB/s) - ‘physionet.org/pn6/chbmit/chb01/index.html?C=M;O=A’ saved [8320]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/chb01/?C=S;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb01/index.html?C=S;O=A’
#
# physionet.org/pn6/c     [ <=>                ]   8.12K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:47 (83.2 MB/s) - ‘physionet.org/pn6/chbmit/chb01/index.html?C=S;O=A’ saved [8320]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/chb01/?C=D;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb01/index.html?C=D;O=A’
#
# physionet.org/pn6/c     [ <=>                ]   8.12K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:47 (92.9 MB/s) - ‘physionet.org/pn6/chbmit/chb01/index.html?C=D;O=A’ saved [8320]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/chb01/MD5SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2418 (2.4K)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/MD5SUMS’
#
# physionet.org/pn6/c 100%[===================>]   2.36K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:47 (280 MB/s) - ‘physionet.org/pn6/chbmit/chb01/MD5SUMS’ saved [2418/2418]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/chb01/SHA1SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2868 (2.8K)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/SHA1SUMS’
#
# physionet.org/pn6/c 100%[===================>]   2.80K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:47 (376 MB/s) - ‘physionet.org/pn6/chbmit/chb01/SHA1SUMS’ saved [2868/2868]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/chb01/SHA256SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4167 (4.1K)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/SHA256SUMS’
#
# physionet.org/pn6/c 100%[===================>]   4.07K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:47 (94.1 MB/s) - ‘physionet.org/pn6/chbmit/chb01/SHA256SUMS’ saved [4167/4167]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/chb01/chb01-summary.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 5355 (5.2K) [text/plain]
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01-summary.txt’
#
# physionet.org/pn6/c 100%[===================>]   5.23K  --.-KB/s    in 0s
#
# 2019-05-29 15:03:47 (117 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01-summary.txt’ saved [5355/5355]
#
# --2019-05-29 15:03:47--  https://physionet.org/pn6/chbmit/chb01/chb01_01.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_01.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.2MB/s    in 1.5s
#
# 2019-05-29 15:03:49 (27.2 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_01.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:03:49--  https://physionet.org/pn6/chbmit/chb01/chb01_02.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_02.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.5MB/s    in 1.5s
#
# 2019-05-29 15:03:50 (27.5 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_02.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:03:50--  https://physionet.org/pn6/chbmit/chb01/chb01_03.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_03.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  30.1MB/s    in 1.3s
#
# 2019-05-29 15:03:52 (30.1 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_03.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:03:52--  https://physionet.org/pn6/chbmit/chb01/chb01_03.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_03.edf.seizures’
#
# physionet.org/pn6/c 100%[===================>]      54  --.-KB/s    in 0s
#
# 2019-05-29 15:03:52 (10.5 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_03.edf.seizures’ saved [54/54]
#
# --2019-05-29 15:03:52--  https://physionet.org/pn6/chbmit/chb01/chb01_04.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_04.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.7MB/s    in 1.5s
#
# 2019-05-29 15:03:53 (27.7 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_04.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:03:53--  https://physionet.org/pn6/chbmit/chb01/chb01_04.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_04.edf.seizures’
#
# physionet.org/pn6/c 100%[===================>]      54  --.-KB/s    in 0s
#
# 2019-05-29 15:03:53 (10.1 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_04.edf.seizures’ saved [54/54]
#
# --2019-05-29 15:03:53--  https://physionet.org/pn6/chbmit/chb01/chb01_05.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_05.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.8MB/s    in 1.5s
#
# 2019-05-29 15:03:55 (27.8 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_05.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:03:55--  https://physionet.org/pn6/chbmit/chb01/chb01_06.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_06.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  28.2MB/s    in 1.4s
#
# 2019-05-29 15:03:56 (28.2 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_06.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:03:56--  https://physionet.org/pn6/chbmit/chb01/chb01_07.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_07.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.3MB/s    in 1.5s
#
# 2019-05-29 15:03:58 (27.3 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_07.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:03:58--  https://physionet.org/pn6/chbmit/chb01/chb01_08.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_08.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  30.9MB/s    in 1.3s
#
# 2019-05-29 15:03:59 (30.9 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_08.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:03:59--  https://physionet.org/pn6/chbmit/chb01/chb01_09.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_09.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.1MB/s    in 1.5s
#
# 2019-05-29 15:04:00 (27.1 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_09.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:00--  https://physionet.org/pn6/chbmit/chb01/chb01_10.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_10.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.0MB/s    in 1.3s
#
# 2019-05-29 15:04:02 (31.0 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_10.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:02--  https://physionet.org/pn6/chbmit/chb01/chb01_11.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_11.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.4MB/s    in 1.3s
#
# 2019-05-29 15:04:03 (31.4 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_11.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:03--  https://physionet.org/pn6/chbmit/chb01/chb01_12.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_12.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.3MB/s    in 1.3s
#
# 2019-05-29 15:04:04 (31.3 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_12.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:04--  https://physionet.org/pn6/chbmit/chb01/chb01_13.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_13.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.4MB/s    in 1.3s
#
# 2019-05-29 15:04:06 (31.4 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_13.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:06--  https://physionet.org/pn6/chbmit/chb01/chb01_14.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_14.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.4MB/s    in 1.3s
#
# 2019-05-29 15:04:07 (31.4 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_14.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:07--  https://physionet.org/pn6/chbmit/chb01/chb01_15.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_15.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  17.8MB/s    in 2.3s
#
# 2019-05-29 15:04:09 (17.8 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_15.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:09--  https://physionet.org/pn6/chbmit/chb01/chb01_15.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_15.edf.seizures’
#
# physionet.org/pn6/c 100%[===================>]      54  --.-KB/s    in 0s
#
# 2019-05-29 15:04:09 (7.92 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_15.edf.seizures’ saved [54/54]
#
# --2019-05-29 15:04:09--  https://physionet.org/pn6/chbmit/chb01/chb01_16.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_16.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.3MB/s    in 1.3s
#
# 2019-05-29 15:04:11 (31.3 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_16.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:11--  https://physionet.org/pn6/chbmit/chb01/chb01_16.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_16.edf.seizures’
#
# physionet.org/pn6/c 100%[===================>]      54  --.-KB/s    in 0s
#
# 2019-05-29 15:04:11 (7.72 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_16.edf.seizures’ saved [54/54]
#
# --2019-05-29 15:04:11--  https://physionet.org/pn6/chbmit/chb01/chb01_17.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_17.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.0MB/s    in 1.5s
#
# 2019-05-29 15:04:12 (27.0 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_17.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:12--  https://physionet.org/pn6/chbmit/chb01/chb01_18.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_18.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.8MB/s    in 1.5s
#
# 2019-05-29 15:04:14 (27.8 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_18.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:14--  https://physionet.org/pn6/chbmit/chb01/chb01_18.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_18.edf.seizures’
#
# physionet.org/pn6/c 100%[===================>]      54  --.-KB/s    in 0s
#
# 2019-05-29 15:04:14 (7.83 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_18.edf.seizures’ saved [54/54]
#
# --2019-05-29 15:04:14--  https://physionet.org/pn6/chbmit/chb01/chb01_19.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_19.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.4MB/s    in 1.3s
#
# 2019-05-29 15:04:15 (31.4 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_19.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:15--  https://physionet.org/pn6/chbmit/chb01/chb01_20.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 31365632 (30M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_20.edf’
#
# physionet.org/pn6/c 100%[===================>]  29.91M  31.3MB/s    in 1.0s
#
# 2019-05-29 15:04:16 (31.3 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_20.edf’ saved [31365632/31365632]
#
# --2019-05-29 15:04:16--  https://physionet.org/pn6/chbmit/chb01/chb01_21.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_21.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.2MB/s    in 1.5s
#
# 2019-05-29 15:04:18 (27.2 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_21.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:18--  https://physionet.org/pn6/chbmit/chb01/chb01_21.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_21.edf.seizures’
#
# physionet.org/pn6/c 100%[===================>]      54  --.-KB/s    in 0s
#
# 2019-05-29 15:04:18 (10.3 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_21.edf.seizures’ saved [54/54]
#
# --2019-05-29 15:04:18--  https://physionet.org/pn6/chbmit/chb01/chb01_22.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_22.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.2MB/s    in 1.5s
#
# 2019-05-29 15:04:19 (27.2 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_22.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:19--  https://physionet.org/pn6/chbmit/chb01/chb01_23.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_23.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.2MB/s    in 1.5s
#
# 2019-05-29 15:04:21 (27.2 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_23.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:21--  https://physionet.org/pn6/chbmit/chb01/chb01_24.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_24.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  30.7MB/s    in 1.3s
#
# 2019-05-29 15:04:22 (30.7 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_24.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:22--  https://physionet.org/pn6/chbmit/chb01/chb01_25.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_25.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.1MB/s    in 1.5s
#
# 2019-05-29 15:04:24 (27.1 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_25.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:24--  https://physionet.org/pn6/chbmit/chb01/chb01_26.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 27385344 (26M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_26.edf’
#
# physionet.org/pn6/c 100%[===================>]  26.12M  26.6MB/s    in 1.0s
#
# 2019-05-29 15:04:25 (26.6 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_26.edf’ saved [27385344/27385344]
#
# --2019-05-29 15:04:25--  https://physionet.org/pn6/chbmit/chb01/chb01_26.edf.seizures
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 54
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_26.edf.seizures’
#
# physionet.org/pn6/c 100%[===================>]      54  --.-KB/s    in 0s
#
# 2019-05-29 15:04:25 (2.62 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_26.edf.seizures’ saved [54/54]
#
# --2019-05-29 15:04:25--  https://physionet.org/pn6/chbmit/chb01/chb01_27.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7071744 (6.7M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_27.edf’
#
# physionet.org/pn6/c 100%[===================>]   6.74M  24.6MB/s    in 0.3s
#
# 2019-05-29 15:04:25 (24.6 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_27.edf’ saved [7071744/7071744]
#
# --2019-05-29 15:04:25--  https://physionet.org/pn6/chbmit/chb01/chb01_29.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_29.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.5MB/s    in 1.3s
#
# 2019-05-29 15:04:26 (31.5 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_29.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:26--  https://physionet.org/pn6/chbmit/chb01/chb01_30.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_30.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  26.7MB/s    in 1.5s
#
# 2019-05-29 15:04:28 (26.7 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_30.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:28--  https://physionet.org/pn6/chbmit/chb01/chb01_31.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_31.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  30.5MB/s    in 1.3s
#
# 2019-05-29 15:04:29 (30.5 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_31.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:29--  https://physionet.org/pn6/chbmit/chb01/chb01_32.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_32.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.3MB/s    in 1.3s
#
# 2019-05-29 15:04:31 (31.3 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_32.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:31--  https://physionet.org/pn6/chbmit/chb01/chb01_33.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_33.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.2MB/s    in 1.5s
#
# 2019-05-29 15:04:32 (27.2 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_33.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:32--  https://physionet.org/pn6/chbmit/chb01/chb01_34.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_34.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.4MB/s    in 1.3s
#
# 2019-05-29 15:04:33 (31.4 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_34.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:33--  https://physionet.org/pn6/chbmit/chb01/chb01_36.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_36.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.1MB/s    in 1.5s
#
# 2019-05-29 15:04:35 (27.1 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_36.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:35--  https://physionet.org/pn6/chbmit/chb01/chb01_37.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_37.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.4MB/s    in 1.3s
#
# 2019-05-29 15:04:36 (31.4 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_37.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:36--  https://physionet.org/pn6/chbmit/chb01/chb01_38.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_38.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.1MB/s    in 1.5s
#
# 2019-05-29 15:04:38 (27.1 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_38.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:38--  https://physionet.org/pn6/chbmit/chb01/chb01_39.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_39.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  30.2MB/s    in 1.3s
#
# 2019-05-29 15:04:39 (30.2 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_39.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:39--  https://physionet.org/pn6/chbmit/chb01/chb01_40.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_40.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  27.0MB/s    in 1.5s
#
# 2019-05-29 15:04:41 (27.0 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_40.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:41--  https://physionet.org/pn6/chbmit/chb01/chb01_41.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_41.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.5MB/s    in 1.3s
#
# 2019-05-29 15:04:42 (31.5 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_41.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:42--  https://physionet.org/pn6/chbmit/chb01/chb01_42.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_42.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  24.9MB/s    in 1.6s
#
# 2019-05-29 15:04:44 (24.9 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_42.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:44--  https://physionet.org/pn6/chbmit/chb01/chb01_43.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_43.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.0MB/s    in 1.3s
#
# 2019-05-29 15:04:45 (31.0 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_43.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:45--  https://physionet.org/pn6/chbmit/chb01/chb01_46.edf
# Connecting to physionet.org (physionet.org)|128.30.30.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb01/chb01_46.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  29.2MB/s    in 1.4s
#
# 2019-05-29 15:04:47 (29.2 MB/s) - ‘physionet.org/pn6/chbmit/chb01/chb01_46.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:47--  https://physionet.org/pn6/chbmit/chb02/?C=N;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6866 (6.7K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb02/index.html?C=N;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.71K  --.-KB/s    in 0s
#
# 2019-05-29 15:04:47 (115 MB/s) - ‘physionet.org/pn6/chbmit/chb02/index.html?C=N;O=D’ saved [6866/6866]
#
# --2019-05-29 15:04:47--  https://physionet.org/pn6/chbmit/chb02/?C=M;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6866 (6.7K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb02/index.html?C=M;O=A’
#
# physionet.org/pn6/c 100%[===================>]   6.71K  --.-KB/s    in 0s
#
# 2019-05-29 15:04:47 (141 MB/s) - ‘physionet.org/pn6/chbmit/chb02/index.html?C=M;O=A’ saved [6866/6866]
#
# --2019-05-29 15:04:47--  https://physionet.org/pn6/chbmit/chb02/?C=S;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6866 (6.7K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb02/index.html?C=S;O=A’
#
# physionet.org/pn6/c 100%[===================>]   6.71K  --.-KB/s    in 0s
#
# 2019-05-29 15:04:47 (79.1 MB/s) - ‘physionet.org/pn6/chbmit/chb02/index.html?C=S;O=A’ saved [6866/6866]
#
# --2019-05-29 15:04:47--  https://physionet.org/pn6/chbmit/chb02/?C=D;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6866 (6.7K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb02/index.html?C=D;O=A’
#
# physionet.org/pn6/c 100%[===================>]   6.71K  --.-KB/s    in 0s
#
# 2019-05-29 15:04:47 (143 MB/s) - ‘physionet.org/pn6/chbmit/chb02/index.html?C=D;O=A’ saved [6866/6866]
#
# --2019-05-29 15:04:47--  https://physionet.org/pn6/chbmit/chb02/MD5SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1914 (1.9K)
# Saving to: ‘physionet.org/pn6/chbmit/chb02/MD5SUMS’
#
# physionet.org/pn6/c 100%[===================>]   1.87K  --.-KB/s    in 0s
#
# 2019-05-29 15:04:47 (327 MB/s) - ‘physionet.org/pn6/chbmit/chb02/MD5SUMS’ saved [1914/1914]
#
# --2019-05-29 15:04:47--  https://physionet.org/pn6/chbmit/chb02/SHA1SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2284 (2.2K)
# Saving to: ‘physionet.org/pn6/chbmit/chb02/SHA1SUMS’
#
# physionet.org/pn6/c 100%[===================>]   2.23K  --.-KB/s    in 0s
#
# 2019-05-29 15:04:47 (386 MB/s) - ‘physionet.org/pn6/chbmit/chb02/SHA1SUMS’ saved [2284/2284]
#
# --2019-05-29 15:04:47--  https://physionet.org/pn6/chbmit/chb02/SHA256SUMS
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3343 (3.3K)
# Saving to: ‘physionet.org/pn6/chbmit/chb02/SHA256SUMS’
#
# physionet.org/pn6/c 100%[===================>]   3.26K  --.-KB/s    in 0s
#
# 2019-05-29 15:04:47 (583 MB/s) - ‘physionet.org/pn6/chbmit/chb02/SHA256SUMS’ saved [3343/3343]
#
# --2019-05-29 15:04:47--  https://physionet.org/pn6/chbmit/chb02/chb02-summary.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4471 (4.4K) [text/plain]
# Saving to: ‘physionet.org/pn6/chbmit/chb02/chb02-summary.txt’
#
# physionet.org/pn6/c 100%[===================>]   4.37K  --.-KB/s    in 0s
#
# 2019-05-29 15:04:47 (120 MB/s) - ‘physionet.org/pn6/chbmit/chb02/chb02-summary.txt’ saved [4471/4471]
#
# --2019-05-29 15:04:47--  https://physionet.org/pn6/chbmit/chb02/chb02_01.edf
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 42399744 (40M)
# Saving to: ‘physionet.org/pn6/chbmit/chb02/chb02_01.edf’
#
# physionet.org/pn6/c 100%[===================>]  40.44M  31.3MB/s    in 1.3s
#
# 2019-05-29 15:04:48 (31.3 MB/s) - ‘physionet.org/pn6/chbmit/chb02/chb02_01.edf’ saved [42399744/42399744]
#
# --2019-05-29 15:04:48--  https://physionet.org/pn6/chbmit/chb02/chb02_02.edf
# ...
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb16/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4903 (4.8K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb16/index.html?C=M;O=D’
#
# physionet.org/pn6/c 100%[===================>]   4.79K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (42.2 MB/s) - ‘physionet.org/pn6/chbmit/chb16/index.html?C=M;O=D’ saved [4903/4903]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb16/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4903 (4.8K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb16/index.html?C=S;O=D’
#
# physionet.org/pn6/c 100%[===================>]   4.79K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (107 MB/s) - ‘physionet.org/pn6/chbmit/chb16/index.html?C=S;O=D’ saved [4903/4903]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb16/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4903 (4.8K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb16/index.html?C=D;O=D’
#
# physionet.org/pn6/c 100%[===================>]   4.79K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (103 MB/s) - ‘physionet.org/pn6/chbmit/chb16/index.html?C=D;O=D’ saved [4903/4903]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb17/?C=N;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4758 (4.6K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb17/index.html?C=N;O=A’
#
# physionet.org/pn6/c 100%[===================>]   4.65K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (24.1 MB/s) - ‘physionet.org/pn6/chbmit/chb17/index.html?C=N;O=A’ saved [4758/4758]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb17/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4758 (4.6K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb17/index.html?C=M;O=D’
#
# physionet.org/pn6/c 100%[===================>]   4.65K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (93.5 MB/s) - ‘physionet.org/pn6/chbmit/chb17/index.html?C=M;O=D’ saved [4758/4758]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb17/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4758 (4.6K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb17/index.html?C=S;O=D’
#
# physionet.org/pn6/c 100%[===================>]   4.65K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (81.7 MB/s) - ‘physionet.org/pn6/chbmit/chb17/index.html?C=S;O=D’ saved [4758/4758]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb17/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4758 (4.6K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb17/index.html?C=D;O=D’
#
# physionet.org/pn6/c 100%[===================>]   4.65K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (80.9 MB/s) - ‘physionet.org/pn6/chbmit/chb17/index.html?C=D;O=D’ saved [4758/4758]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb18/?C=N;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7317 (7.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb18/index.html?C=N;O=A’
#
# physionet.org/pn6/c 100%[===================>]   7.15K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (157 MB/s) - ‘physionet.org/pn6/chbmit/chb18/index.html?C=N;O=A’ saved [7317/7317]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb18/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7317 (7.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb18/index.html?C=M;O=D’
#
# physionet.org/pn6/c 100%[===================>]   7.15K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (147 MB/s) - ‘physionet.org/pn6/chbmit/chb18/index.html?C=M;O=D’ saved [7317/7317]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb18/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7317 (7.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb18/index.html?C=S;O=D’
#
# physionet.org/pn6/c 100%[===================>]   7.15K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (110 MB/s) - ‘physionet.org/pn6/chbmit/chb18/index.html?C=S;O=D’ saved [7317/7317]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb18/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7317 (7.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb18/index.html?C=D;O=D’
#
# physionet.org/pn6/c 100%[===================>]   7.15K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (95.4 MB/s) - ‘physionet.org/pn6/chbmit/chb18/index.html?C=D;O=D’ saved [7317/7317]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb19/?C=N;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6012 (5.9K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb19/index.html?C=N;O=A’
#
# physionet.org/pn6/c 100%[===================>]   5.87K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (114 MB/s) - ‘physionet.org/pn6/chbmit/chb19/index.html?C=N;O=A’ saved [6012/6012]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb19/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6012 (5.9K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb19/index.html?C=M;O=D’
#
# physionet.org/pn6/c 100%[===================>]   5.87K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (104 MB/s) - ‘physionet.org/pn6/chbmit/chb19/index.html?C=M;O=D’ saved [6012/6012]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb19/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6012 (5.9K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb19/index.html?C=S;O=D’
#
# physionet.org/pn6/c 100%[===================>]   5.87K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (78.5 MB/s) - ‘physionet.org/pn6/chbmit/chb19/index.html?C=S;O=D’ saved [6012/6012]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb19/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6012 (5.9K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb19/index.html?C=D;O=D’
#
# physionet.org/pn6/c 100%[===================>]   5.87K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (139 MB/s) - ‘physionet.org/pn6/chbmit/chb19/index.html?C=D;O=D’ saved [6012/6012]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb20/?C=N;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6323 (6.2K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb20/index.html?C=N;O=A’
#
# physionet.org/pn6/c 100%[===================>]   6.17K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (154 MB/s) - ‘physionet.org/pn6/chbmit/chb20/index.html?C=N;O=A’ saved [6323/6323]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb20/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6323 (6.2K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb20/index.html?C=M;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.17K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (135 MB/s) - ‘physionet.org/pn6/chbmit/chb20/index.html?C=M;O=D’ saved [6323/6323]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb20/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6323 (6.2K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb20/index.html?C=S;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.17K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (154 MB/s) - ‘physionet.org/pn6/chbmit/chb20/index.html?C=S;O=D’ saved [6323/6323]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb20/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6323 (6.2K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb20/index.html?C=D;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.17K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (166 MB/s) - ‘physionet.org/pn6/chbmit/chb20/index.html?C=D;O=D’ saved [6323/6323]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb21/?C=N;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6589 (6.4K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb21/index.html?C=N;O=A’
#
# physionet.org/pn6/c 100%[===================>]   6.43K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (162 MB/s) - ‘physionet.org/pn6/chbmit/chb21/index.html?C=N;O=A’ saved [6589/6589]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb21/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6589 (6.4K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb21/index.html?C=M;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.43K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (131 MB/s) - ‘physionet.org/pn6/chbmit/chb21/index.html?C=M;O=D’ saved [6589/6589]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb21/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6589 (6.4K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb21/index.html?C=S;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.43K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:57 (172 MB/s) - ‘physionet.org/pn6/chbmit/chb21/index.html?C=S;O=D’ saved [6589/6589]
#
# --2019-05-29 15:31:57--  https://physionet.org/pn6/chbmit/chb21/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6589 (6.4K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb21/index.html?C=D;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.43K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (142 MB/s) - ‘physionet.org/pn6/chbmit/chb21/index.html?C=D;O=D’ saved [6589/6589]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb22/?C=N;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6154 (6.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb22/index.html?C=N;O=A’
#
# physionet.org/pn6/c 100%[===================>]   6.01K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (113 MB/s) - ‘physionet.org/pn6/chbmit/chb22/index.html?C=N;O=A’ saved [6154/6154]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb22/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6154 (6.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb22/index.html?C=M;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.01K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (162 MB/s) - ‘physionet.org/pn6/chbmit/chb22/index.html?C=M;O=D’ saved [6154/6154]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb22/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6154 (6.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb22/index.html?C=S;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.01K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (123 MB/s) - ‘physionet.org/pn6/chbmit/chb22/index.html?C=S;O=D’ saved [6154/6154]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb22/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6154 (6.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb22/index.html?C=D;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.01K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (139 MB/s) - ‘physionet.org/pn6/chbmit/chb22/index.html?C=D;O=D’ saved [6154/6154]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb23/?C=N;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3030 (3.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb23/index.html?C=N;O=A’
#
# physionet.org/pn6/c 100%[===================>]   2.96K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (516 MB/s) - ‘physionet.org/pn6/chbmit/chb23/index.html?C=N;O=A’ saved [3030/3030]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb23/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3030 (3.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb23/index.html?C=M;O=D’
#
# physionet.org/pn6/c 100%[===================>]   2.96K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (532 MB/s) - ‘physionet.org/pn6/chbmit/chb23/index.html?C=M;O=D’ saved [3030/3030]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb23/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3030 (3.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb23/index.html?C=S;O=D’
#
# physionet.org/pn6/c 100%[===================>]   2.96K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (576 MB/s) - ‘physionet.org/pn6/chbmit/chb23/index.html?C=S;O=D’ saved [3030/3030]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb23/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 3030 (3.0K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb23/index.html?C=D;O=D’
#
# physionet.org/pn6/c 100%[===================>]   2.96K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (561 MB/s) - ‘physionet.org/pn6/chbmit/chb23/index.html?C=D;O=D’ saved [3030/3030]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb24/?C=N;O=A
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6235 (6.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb24/index.html?C=N;O=A’
#
# physionet.org/pn6/c 100%[===================>]   6.09K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (90.1 MB/s) - ‘physionet.org/pn6/chbmit/chb24/index.html?C=N;O=A’ saved [6235/6235]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb24/?C=M;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6235 (6.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb24/index.html?C=M;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.09K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (112 MB/s) - ‘physionet.org/pn6/chbmit/chb24/index.html?C=M;O=D’ saved [6235/6235]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb24/?C=S;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6235 (6.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb24/index.html?C=S;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.09K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (119 MB/s) - ‘physionet.org/pn6/chbmit/chb24/index.html?C=S;O=D’ saved [6235/6235]
#
# --2019-05-29 15:31:58--  https://physionet.org/pn6/chbmit/chb24/?C=D;O=D
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 6235 (6.1K) [text/html]
# Saving to: ‘physionet.org/pn6/chbmit/chb24/index.html?C=D;O=D’
#
# physionet.org/pn6/c 100%[===================>]   6.09K  --.-KB/s    in 0s
#
# 2019-05-29 15:31:58 (77.2 MB/s) - ‘physionet.org/pn6/chbmit/chb24/index.html?C=D;O=D’ saved [6235/6235]
#
# FINISHED --2019-05-29 15:31:58--
# Total wall clock time: 28m 14s
# Downloaded: 1159 files, 43G in 27m 17s (26.7 MB/s)

# %%
# !mv /content/chb19-summary.txt /content/physionet.org/pn6/chbmit/chb19
# Out:
# mv: cannot stat '/content/chb19-summary.txt': No such file or directory

# %% [markdown]
# **DataGram/Spectogram**

# %%
import os
from datetime import datetime, timedelta

import matplotlib.pyplot as plt
import numpy as np
import pyedflib
from scipy import signal
from scipy.signal import butter, lfilter

# DATASET: https://physionet.org/pn6/chbmit/
sampleRate = 256
pathDataSet = './physionet.org/pn6/chbmit/'  # path of the dataset
FirstPartPathOutput = './project/dataset/spectograms'  # path where the spectogram will be saved
#patients = ["01", "02", "03", "05", "09", "10", "14", "18", "19", "21", "23"]
# nSeizure = [7, 3, 6, 5, 4, 6, 5, 5, 6, 3, 5, 4, 5]
patients = ["09", "10", "14", "18"]
_30_MINUTES_OF_DATA = 256 * 60 * 30
_MINUTES_OF_DATA_BETWEEN_PRE_AND_SEIZURE = 3  # In theory 5 as the SPH but set to 3 to consider some seizure taken in the paperrese nel paper
_MINUTES_OF_PREICTAL = 30
_SIZE_WINDOW_IN_SECONDS = 30
_SIZE_WINDOW_SPECTOGRAM = _SIZE_WINDOW_IN_SECONDS * 256
nSpectogram = 0
signalsBlock = None
SecondPartPathOutput = ''
legendOfOutput = ''
isPreictal = ''


def loadParametersFromFile(filePath):
    global pathDataSet
    global FirstPartPathOutput
    if os.path.isfile(filePath):
        with open(filePath, "r") as f:
            line = f.readline()
            if line.split(":")[0] == "pathDataSet":
                pathDataSet = line.split(":")[1].strip()
            line = f.readline()
            if line.split(":")[0] == "FirstPartPathOutput":
                FirstPartPathOutput = line.split(":")[1].strip()


# Band size filter
def butter_bandstop_filter(data, lowcut, highcut, fs, order):
    nyq = 0.5 * fs
    low = lowcut / nyq
    high = highcut / nyq

    i, u = butter(order, [low, high], btype='bandstop')
    y = lfilter(i, u, data)
    return y


# Band size filter,high pass
def butter_highpass_filter(data, cutoff, fs, order=5):
    nyq = 0.5 * fs
    normal_cutoff = cutoff / nyq
    b, a = butter(order, normal_cutoff, btype='high', analog=False)
    y = lfilter(b, a, data)
    return y


# Creating the pointer to the patient file with index equal to index
def loadSummaryPatient(index):
    f = open(pathDataSet + 'chb' + patients[index] + '/chb' + patients[index] + '-summary.txt', 'r')
    return f


# Caricamento dei dati di un paziente(indexPatient). I dati sono presi dal file con il nome indicato in fileOfData
# Restituisce un vettore numpy con i dati del paziente contenuti nel file
def loadDataOfPatient(indexPatient, fileOfData):
    f = pyedflib.EdfReader(pathDataSet + 'chb' + patients[
        indexPatient] + '/' + fileOfData)  # https://pyedflib.readthedocs.io/en/latest/#description
    n = f.signals_in_file
    sigbufs = np.zeros((n, f.getNSamples()[0]))
    for i in np.arange(n):
        sigbufs[i, :] = f.readSignal(i)
    sigbufs = cleanData(sigbufs, indexPatient)
    return sigbufs


def cleanData(Data, indexPatient):
    if (patients[indexPatient] in ["19", "21"]):
        Data = np.delete(Data, 22, axis=0)
        Data = np.delete(Data, 17, axis=0)
        Data = np.delete(Data, 12, axis=0)
        Data = np.delete(Data, 9, axis=0)
        Data = np.delete(Data, 4, axis=0)
    return Data


def getTime(dateInString):
    time = 0
    try:
        time = datetime.strptime(dateInString, '%H:%M:%S')
    except ValueError:
        dateInString = " " + dateInString
        if (' 24' in dateInString):
            dateInString = dateInString.replace(' 24', '23')
            time = datetime.strptime(dateInString, '%H:%M:%S')
            time += timedelta(hours=1)
        else:
            dateInString = dateInString.replace(' 25', '23')
            time = datetime.strptime(dateInString, '%H:%M:%S')
            time += timedelta(hours=2)
    return time


def saveSignalsOnDisk(signalsBlock, nSpectogram):
    global SecondPartPathOutput
    global FirstPartPathOutput
    global legendOfOutput
    global isPreictal

    if not os.path.exists(FirstPartPathOutput):
        os.makedirs(FirstPartPathOutput)
    if not os.path.exists(FirstPartPathOutput + SecondPartPathOutput):
        os.makedirs(FirstPartPathOutput + SecondPartPathOutput)
    np.save(FirstPartPathOutput + SecondPartPathOutput + '/spec_' + isPreictal + '_' + str(
        nSpectogram - signalsBlock.shape[0]) + '_' + str(nSpectogram - 1), signalsBlock)
    legendOfOutput = legendOfOutput + str(nSpectogram - signalsBlock.shape[0]) + ' ' + str(
        nSpectogram - 1) + ' ' + SecondPartPathOutput + '/spec_' + isPreictal + '_' + str(
        nSpectogram - signalsBlock.shape[0]) + '_' + str(nSpectogram - 1) + '.npy\n'


def createSpectrogram(data, S=0):
    global nSpectogram
    global signalsBlock
    global inB
    signals = np.zeros((22, 59, 114))

    t = 0
    movement = int(S * 256)
    if (S == 0):
        movement = _SIZE_WINDOW_SPECTOGRAM
    while data.shape[1] - (t * movement + _SIZE_WINDOW_SPECTOGRAM) > 0:
        # CREAZIONE DELLO SPETROGRAMMA PER TUTTI I CANALI
        for i in range(0, 22):
            start = t * movement
            stop = start + _SIZE_WINDOW_SPECTOGRAM
            signals[i, :] = createSpec(data[i, start:stop])
        if (signalsBlock is None):
            signalsBlock = np.array([signals])
        else:
            signalsBlock = np.append(signalsBlock, [signals], axis=0)
        nSpectogram = nSpectogram + 1
        if (signalsBlock.shape[0] == 50):
            saveSignalsOnDisk(signalsBlock, nSpectogram)
            signalsBlock = None
            # SALVATAGGIO DI SIGNALS  
        t = t + 1
    return (data.shape[1] - t * _SIZE_WINDOW_SPECTOGRAM) * -1


def createSpec(data):
    fs = 256
    lowcut = 117
    highcut = 123

    y = butter_bandstop_filter(data, lowcut, highcut, fs, order=6)
    lowcut = 57
    highcut = 63
    y = butter_bandstop_filter(y, lowcut, highcut, fs, order=6)

    cutoff = 1
    y = butter_highpass_filter(y, cutoff, fs, order=6)

    Pxx = signal.spectrogram(y, nfft=256, fs=256, return_onesided=True, noverlap=128)[2]
    Pxx = np.delete(Pxx, np.s_[117:123 + 1], axis=0)
    Pxx = np.delete(Pxx, np.s_[57:63 + 1], axis=0)
    Pxx = np.delete(Pxx, 0, axis=0)

    result = (10 * np.log10(np.transpose(Pxx)) - (10 * np.log10(np.transpose(Pxx))).min()) / (
            10 * np.log10(np.transpose(Pxx))).ptp()
    return result


def createSpecAndPlot(data):
    freqs, bins, Pxx = signal.spectrogram(data, nfft=256, fs=256, return_onesided=True, noverlap=128)

    print("Original")
    plt.pcolormesh(freqs, bins, 10 * np.log10(np.transpose(Pxx)), cmap=plt.cm.jet)
    plt.colorbar()
    plt.ylabel('sec')
    plt.xlabel('Hz')
    plt.title('Spettrogramma')
    plt.show()
    plt.close()

    fs = 256
    lowcut = 117
    highcut = 123

    y = butter_bandstop_filter(data, lowcut, highcut, fs, order=6)
    lowcut = 57
    highcut = 63
    y = butter_bandstop_filter(y, lowcut, highcut, fs, order=6)

    cutoff = 1
    y = butter_highpass_filter(y, cutoff, fs, order=6)

    # Pxx=signal.spectrogram(y, nfft=256, fs=256, return_onesided=True, noverlap=128)[2]
    freqs, bins, Pxx = signal.spectrogram(y, nfft=256, fs=256, return_onesided=True, noverlap=128)

    print("Filtered")
    plt.pcolormesh(freqs, bins, 10 * np.log10(np.transpose(Pxx)), cmap=plt.cm.jet)
    plt.colorbar()
    plt.ylabel('sec')
    plt.xlabel('Hz')
    plt.title('Spettrogramma')
    plt.show()
    plt.close()

    Pxx = np.delete(Pxx, np.s_[117:123 + 1], axis=0)
    Pxx = np.delete(Pxx, np.s_[57:63 + 1], axis=0)
    Pxx = np.delete(Pxx, 0, axis=0)

    print("Cleaned but not standard")
    freqs = np.arange(Pxx.shape[0])
    plt.pcolormesh(freqs, bins, 10 * np.log10(np.transpose(Pxx)), cmap=plt.cm.jet)
    plt.colorbar()
    plt.ylabel('sec')
    plt.xlabel('Hz')
    plt.title('Spettrogramma')
    plt.show()
    plt.close()

    result = (10 * np.log10(np.transpose(Pxx)) - (10 * np.log10(np.transpose(Pxx))).min()) / (
            10 * np.log10(np.transpose(Pxx))).ptp()

    print("Standard")
    freqs = np.arange(result.shape[1])
    plt.pcolormesh(freqs, bins, result, cmap=plt.cm.jet)
    plt.colorbar()
    plt.ylabel('sec')
    plt.xlabel('Hz')
    plt.title('Spettrogramma')
    plt.show()
    plt.close()

    return result


class PreIntData:
    start = 0
    end = 0

    def __init__(self, s, e):
        self.start = s
        self.end = e


class FileData:
    start = 0
    end = 0
    nameFile = ""

    def __init__(self, s, e, nF):
        self.start = s
        self.end = e
        self.nameFile = nF


def createArrayIntervalData(fSummary):
    preictalInteval = []
    interictalInterval = []
    interictalInterval.append(PreIntData(datetime.min, datetime.max))
    files = []
    firstTime = True
    oldTime = datetime.min  # equivalente di 0 nelle date
    startTime = 0
    line = fSummary.readline()
    endS = datetime.min
    while (line):
        data = line.split(':')
        if (data[0] == "File Name"):
            nF = data[1].strip()
            s = getTime((fSummary.readline().split(": "))[1].strip())
            if (firstTime):
                interictalInterval[0].start = s
                firstTime = False
                startTime = s
            while s < oldTime:  # se cambia di giorno aggiungo 24 ore alla data
                s = s + timedelta(hours=24)
            oldTime = s
            endTimeFile = getTime((fSummary.readline().split(": "))[1].strip())
            while endTimeFile < oldTime:  # se cambia di giorno aggiungo 24 ore alla data
                endTimeFile = endTimeFile + timedelta(hours=24)
            oldTime = endTimeFile
            files.append(FileData(s, endTimeFile, nF))
            for j in range(0, int((fSummary.readline()).split(':')[1])):
                secSt = int(fSummary.readline().split(': ')[1].split(' ')[0])
                secEn = int(fSummary.readline().split(': ')[1].split(' ')[0])
                ss = s + timedelta(seconds=secSt) - timedelta(
                    minutes=_MINUTES_OF_DATA_BETWEEN_PRE_AND_SEIZURE + _MINUTES_OF_PREICTAL)
                if ((len(preictalInteval) == 0 or ss > endS) and ss - startTime > timedelta(minutes=20)):
                    ee = ss + timedelta(minutes=_MINUTES_OF_PREICTAL)
                    preictalInteval.append(PreIntData(ss, ee))
                endS = s + timedelta(seconds=secEn)
                ss = s + timedelta(seconds=secSt) - timedelta(hours=4)
                ee = s + timedelta(seconds=secEn) + timedelta(hours=4)
                if (interictalInterval[len(interictalInterval) - 1].start < ss and interictalInterval[
                    len(interictalInterval) - 1].end > ee):
                    interictalInterval[len(interictalInterval) - 1].end = ss
                    interictalInterval.append(PreIntData(ee, datetime.max))
                else:
                    if (interictalInterval[len(interictalInterval) - 1].start < ee):
                        interictalInterval[len(interictalInterval) - 1].start = ee
        line = fSummary.readline()
    fSummary.close()
    interictalInterval[len(interictalInterval) - 1].end = endTimeFile
    return preictalInteval, interictalInterval, files


def main():
    global SecondPartPathOutput
    global FirstPartPathOutput
    global legendOfOutput
    global nSpectogram
    global signalsBlock
    global isPreictal
    print("START \n")
    loadParametersFromFile("PARAMETERS_DATA_EDITING.txt")
    print("Parameters loaded")

    for indexPatient in range(0, len(patients)):
        print("Working on patient " + patients[indexPatient])
        legendOfOutput = ""
        allLegend = ""
        nSpectogram = 0

        SecondPartPathOutput = '/paz' + patients[indexPatient]
        f = loadSummaryPatient(indexPatient)
        preictalInfo, interictalInfo, filesInfo = createArrayIntervalData(f)
        if (patients[indexPatient] == "19"):
            preictalInfo.pop(0)  # Eliminazione dei dati della prima seizure perchè non viene considerata
        print("Summary patient loaded")

        print("START creation interictal spectrogram")
        totInst = 0
        # c=0
        # d=0
        interictalData = np.array([]).reshape(22, 0)
        indexInterictalSegment = 0
        isPreictal = ''
        for fInfo in filesInfo:
            fileS = fInfo.start
            fileE = fInfo.end
            intSegStart = interictalInfo[indexInterictalSegment].start
            intSegEnd = interictalInfo[indexInterictalSegment].end
            while (fileS > intSegEnd and indexInterictalSegment < len(interictalInfo)):
                indexInterictalSegment = indexInterictalSegment + 1
                intSegStart = interictalInfo[indexInterictalSegment].start
                intSegEnd = interictalInfo[indexInterictalSegment].end
            start = 0
            end = 0
            if (not fileE < intSegStart or fileS > intSegEnd):
                if (fileS >= intSegStart):
                    start = 0
                else:
                    start = (intSegStart - fileS).seconds
                if (fileE <= intSegEnd):
                    end = None
                else:
                    end = (intSegEnd - fileS).seconds
                tmpData = loadDataOfPatient(indexPatient, fInfo.nameFile)
                if (not end == None):
                    end = end * 256
                if (tmpData.shape[0] < 22):
                    print(patients[indexPatient] + "  HA UN NUMERO MINORE DI CANALI")
                else:
                    interictalData = np.concatenate((interictalData, tmpData[0:22, start * 256:end]), axis=1)
                    notUsed = createSpectrogram(interictalData)
                    totInst += interictalData.shape[1] / 256 - notUsed / 256
                    interictalData = np.delete(interictalData, np.s_[0:interictalData.shape[1] - notUsed], axis=1)

        # dimensione_finestra:lunghezza_dati_I=S:(lunghezza_dati_P-30_SEC_PER_OGNI_SEIZURE)
        S = (_SIZE_WINDOW_IN_SECONDS * (len(preictalInfo) * _MINUTES_OF_PREICTAL * 60 - _SIZE_WINDOW_IN_SECONDS * len(
            preictalInfo))) / totInst
        if (not (signalsBlock is None)):
            saveSignalsOnDisk(signalsBlock, nSpectogram)
        signalsBlock = None

        print("Spectrogram interictal: " + str(nSpectogram))
        print("Hours interictal: " + str(totInst / 60 / 60))
        legendOfOutput = str(nSpectogram) + "\n" + legendOfOutput
        legendOfOutput = "INTERICTAL" + "\n" + legendOfOutput
        legendOfOutput = "SEIZURE: " + str(len(preictalInfo)) + "\n" + legendOfOutput
        legendOfOutput = patients[indexPatient] + "\n" + legendOfOutput
        allLegend = legendOfOutput
        legendOfOutput = ''
        nSpectogram = 0
        print("END creation interictal spectrogram")
        # FINE ciclo gestione interictal data

        # INIZIO ciclo gestione preictal data
        print("START creation preictal spectrogram")
        isPreictal = 'P'
        contSeizure = -1
        for pInfo in preictalInfo:
            contSeizure = contSeizure + 1
            legendOfOutput = legendOfOutput + "SEIZURE " + str(contSeizure) + "\n"
            preictalData = np.array([]).reshape(22, 0)
            j = 0
            for j in range(0, len(filesInfo)):
                if (pInfo.start >= filesInfo[j].start and pInfo.start < filesInfo[j].end):
                    break
            start = (pInfo.start - filesInfo[j].start).seconds
            if (start < 0):
                start = 0
            end = None
            tmpData = []
            if (pInfo.end <= filesInfo[j].end):
                end = (pInfo.end - filesInfo[j].start).seconds
                tmpData = loadDataOfPatient(indexPatient, filesInfo[j].nameFile)
                preictalData = np.concatenate((preictalData, tmpData[0:22, start * 256:end * 256]), axis=1)
            else:
                tmpData = loadDataOfPatient(indexPatient, filesInfo[j].nameFile)
                preictalData = np.concatenate((preictalData, tmpData[0:22, start * 256:]), axis=1)
                end = (pInfo.end - filesInfo[j + 1].start).seconds
                tmpData = loadDataOfPatient(indexPatient, filesInfo[j + 1].nameFile)
                preictalData = np.concatenate((preictalData, tmpData[0:22, 0:end * 256]), axis=1)
            notUsed = createSpectrogram(preictalData, S=S)
            if (not (signalsBlock is None)):
                saveSignalsOnDisk(signalsBlock, nSpectogram)
            signalsBlock = None

        allLegend = allLegend + "\n" + "PREICTAL" + "\n" + str(nSpectogram) + "\n" + legendOfOutput
        print("Spectrogram preictal: " + str(nSpectogram))
        print("SEIZURE: " + str(len(preictalInfo)))
        print("END creation preictal spectrogram")
        # FINE ciclo gestione preictal data'''

        print("START creation \'real\' preictal spectrogram")
        isPreictal = 'P_R'
        nSpectogram = 0
        contSeizure = -1
        S = 0
        legendOfOutput = ''
        for pInfo in preictalInfo:
            contSeizure = contSeizure + 1
            legendOfOutput = legendOfOutput + "SEIZURE " + str(contSeizure) + "\n"
            preictalData = np.array([]).reshape(22, 0)
            j = 0
            for j in range(0, len(filesInfo)):
                if (pInfo.start >= filesInfo[j].start and pInfo.start < filesInfo[j].end):
                    break
            start = (pInfo.start - filesInfo[j].start).seconds
            if (start < 0):
                start = 0
            end = None
            tmpData = []
            if (pInfo.end <= filesInfo[j].end):
                end = (pInfo.end - filesInfo[j].start).seconds
                tmpData = loadDataOfPatient(indexPatient, filesInfo[j].nameFile)
                preictalData = np.concatenate((preictalData, tmpData[0:22, start * 256:end * 256]), axis=1)
            else:
                tmpData = loadDataOfPatient(indexPatient, filesInfo[j].nameFile)
                preictalData = np.concatenate((preictalData, tmpData[0:22, start * 256:]), axis=1)
                end = (pInfo.end - filesInfo[j + 1].start).seconds
                tmpData = loadDataOfPatient(indexPatient, filesInfo[j + 1].nameFile)
                preictalData = np.concatenate((preictalData, tmpData[0:22, 0:end * 256]), axis=1)
            notUsed = createSpectrogram(preictalData, S=S)
            if (not (signalsBlock is None)):
                saveSignalsOnDisk(signalsBlock, nSpectogram)
            signalsBlock = None

        allLegend = allLegend + "\n" + "REAL_PREICTAL" + "\n" + str(nSpectogram) + "\n" + legendOfOutput
        print("Spectrogram \'REAL\' preictal: " + str(nSpectogram))
        print("END creation \'real\' preictal spectrogram")

        text_file = open(FirstPartPathOutput + SecondPartPathOutput + "/legendAllData.txt", "w")
        text_file.write(allLegend)
        text_file.close()
        print("Legend saved on disk")
        print('\n')
    print("END")


if __name__ == '__main__':
    main()
# Out:
# START
#
# Parameters loaded
# Working on patient 09
# Summary patient loaded
# START creation interictal spectrogram
# Spectrogram interictal: 5821
# Hours interictal: 48.67055555555555
# END creation interictal spectrogram
# START creation preictal spectrogram
# Spectrogram preictal: 5848
# SEIZURE: 4
# END creation preictal spectrogram
# START creation 'real' preictal spectrogram
# Spectrogram 'REAL' preictal: 236
# END creation 'real' preictal spectrogram
# Legend saved on disk
#
#
# Working on patient 10
# Summary patient loaded
# START creation interictal spectrogram
# Spectrogram interictal: 2901
# Hours interictal: 24.37777777777778
# END creation interictal spectrogram
# START creation preictal spectrogram
# Spectrogram preictal: 2514
# SEIZURE: 7
# END creation preictal spectrogram
# START creation 'real' preictal spectrogram
# Spectrogram 'REAL' preictal: 354
# END creation 'real' preictal spectrogram
# Legend saved on disk
#
#
# Working on patient 14
# Summary patient loaded
# START creation interictal spectrogram
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:172: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:172: RuntimeWarning: invalid value encountered in subtract
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:173: RuntimeWarning: divide by zero encountered in log10
# /usr/local/lib/python3.6/dist-packages/numpy/core/_methods.py:155: RuntimeWarning: invalid value encountered in subtract
#   out
# Spectrogram interictal: 561
# Hours interictal: 4.751111111111111
# END creation interictal spectrogram
# START creation preictal spectrogram
# Spectrogram preictal: 383
# SEIZURE: 6
# END creation preictal spectrogram
# START creation 'real' preictal spectrogram
# Spectrogram 'REAL' preictal: 236
# END creation 'real' preictal spectrogram
# Legend saved on disk
#
#
# Working on patient 18
# Summary patient loaded
# START creation interictal spectrogram
# Spectrogram interictal: 3147
# Hours interictal: 26.653333333333332
# END creation interictal spectrogram
# START creation preictal spectrogram
# Spectrogram preictal: 1920
# SEIZURE: 5
# END creation preictal spectrogram
# START creation 'real' preictal spectrogram
# Spectrogram 'REAL' preictal: 177
# END creation 'real' preictal spectrogram
# Legend saved on disk
#
#
# END

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
# os.environ["CUDA_VISIBLE_DEVICES"] = ""
# FINE codice per allenare la rete sulla cpu

import keras
import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Conv3D, Dropout, Flatten, BatchNormalization
from keras.callbacks import EarlyStopping
from random import shuffle
import math

# to plot the model
# from keras.utils.vis_utils import plot_model
# from keras.models import load_model
# Returns a compiled model identical to the saved one
# model = load_model('my_model.h5')

PathSpectogramFolder = './project/dataset/spectograms'
OutputPath = './project/dataset/results.txt'
OutputPathModels = './project/dataset/'
interictalSpectograms = []
preictalSpectograms = []
preictalRealSpectograms = []
#patients = ["01", "02", "03", "05", "09", "10", "13", "14", "18", "19", "20", "21", "23"]
#patients = ["09", "10", "14", "18"]
nSeizure = 0


def loadParametersFromFile(filePath):
    global PathSpectogramFolder
    global OutputPath
    global OutputPathModels
    if (os.path.isfile(filePath)):
        with open(filePath, "r") as f:
            line = f.readline()
            if (line.split(":")[0] == "PathSpectogramFolder"):
                PathSpectogramFolder = line.split(":")[1].strip()
            line = f.readline()
            if (line.split(":")[0] == "OutputPath"):
                OutputPath = line.split(":")[1].strip()
            line = f.readline()
            if (line.split(":")[0] == "OutputPathModels"):
                OutputPathModels = line.split(":")[1].strip()


def loadSpectogramData(indexPat):
    global interictalSpectograms
    global preictalSpectograms
    global preictalRealSpectograms
    global nSeizure
    nFileForSeizure = 0

    interictalSpectograms = []
    preictalSpectograms = []
    preictalRealSpectograms = []

    f = open(PathSpectogramFolder + '/paz' + patients[indexPat] + '/legendAllData.txt', 'r')
    line = f.readline()
    while (not "SEIZURE" in line):
        line = f.readline()
    nSeizure = int(line.split(":")[1].strip())
    line = f.readline()
    line = f.readline()  # legge il numero di spectogrammi. non lo salvo dato che non mi serve
    nSpectograms = int(line.strip())
    nFileForSeizure = math.ceil(math.ceil(nSpectograms / 50) / nSeizure)
    line = f.readline()  # leggo il percorso del primo file

    # Lettura path files Interictal
    cont = -1
    indFilePathRead = 0
    while ("npy" in line and indFilePathRead < nSeizure * nFileForSeizure):
        if (indFilePathRead % nFileForSeizure == 0):
            interictalSpectograms.append([])
            cont = cont + 1
            interictalSpectograms[cont].append(line.split(' ')[2].rstrip())  # .rstrip() remove \n
            indFilePathRead = indFilePathRead + 1
        else:
            if (len(line.split(' ')) >= 3):
                interictalSpectograms[cont].append(line.split(' ')[2].rstrip())
            indFilePathRead = indFilePathRead + 1

        line = f.readline()
    line = f.readline()  # leggo PREICTAL
    line = f.readline()  # leggo n° spectogram
    line = f.readline()  # leggo n°seizure(SEIZURE X)

    cont = -1
    indFilePathRead = 0
    # while(line and indFilePathRead<nSeizure*nFileForSeizure):
    while (line.strip() != ""):
        if ("SEIZURE" in line):
            line = f.readline()  # ho letto n°seizure(SEIZURE X) perciò scorro in avanti
            if (len(line.split(' ')) >= 3):
                preictalSpectograms.append([])
                cont = cont + 1
                preictalSpectograms[cont].append(line.split(' ')[2].rstrip())
                indFilePathRead = indFilePathRead + 1
        else:
            if (len(line.split(' ')) >= 3):
                preictalSpectograms[cont].append(line.split(' ')[2].rstrip())
            indFilePathRead = indFilePathRead + 1

        line = f.readline()

    line = f.readline()  # leggo REAL_PREICTAL
    line = f.readline()  # leggo n° spectogram
    line = f.readline()  # leggo n°seizure(SEIZURE X)

    cont = -1
    while (line):
        if ("SEIZURE" in line):
            line = f.readline()
            preictalRealSpectograms.append([])
            cont = cont + 1
            preictalRealSpectograms[cont].append(line.split(' ')[2].rstrip())
        else:
            preictalRealSpectograms[cont].append(line.split(' ')[2].rstrip())

        line = f.readline()
    f.close()


def createModel():
    input_shape = (1, 22, 59, 114)
    model = Sequential()
    # C1
    model.add(
        Conv3D(16, (22, 5, 5), strides=(1, 2, 2), padding='valid', activation='relu', data_format="channels_first",
               input_shape=input_shape))
    model.add(keras.layers.MaxPooling3D(pool_size=(1, 2, 2), data_format="channels_first", padding='same'))
    model.add(BatchNormalization())

    # C2
    model.add(Conv3D(32, (1, 3, 3), strides=(1, 1, 1), padding='valid', data_format="channels_first",
                     activation='relu'))  # incertezza se togliere padding
    model.add(keras.layers.MaxPooling3D(pool_size=(1, 2, 2), data_format="channels_first", ))
    model.add(BatchNormalization())

    # C3
    model.add(Conv3D(64, (1, 3, 3), strides=(1, 1, 1), padding='valid', data_format="channels_first",
                     activation='relu'))  # incertezza se togliere padding
    model.add(keras.layers.MaxPooling3D(pool_size=(1, 2, 2), data_format="channels_first", ))
    model.add(BatchNormalization())

    model.add(Flatten())
    model.add(Dropout(0.5))
    model.add(Dense(256, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(2, activation='softmax'))

    opt_adam = keras.optimizers.Adam(lr=0.00001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)
    model.compile(loss='categorical_crossentropy', optimizer=opt_adam, metrics=['accuracy'])

    return model


def getFilesPathWithoutSeizure(indexSeizure, indexPat):
    filesPath = []
    for i in range(0, nSeizure):
        if (i != indexSeizure):
            filesPath.extend(interictalSpectograms[i])
            filesPath.extend(preictalSpectograms[i])
    shuffle(filesPath)
    return filesPath


def generate_arrays_for_training(indexPat, paths, start=0, end=100):
    while True:
        from_ = int(len(paths) / 100 * start)
        to_ = int(len(paths) / 100 * end)
        for i in range(from_, int(to_)):
            f = paths[i]
            x = np.load(PathSpectogramFolder + f)
            x = np.array([x])
            x = x.swapaxes(0, 1)
            if ('P' in f):
                y = np.repeat([[0, 1]], x.shape[0], axis=0)
            else:
                y = np.repeat([[1, 0]], x.shape[0], axis=0)
            yield (x, y)


def generate_arrays_for_predict(indexPat, paths, start=0, end=100):
    while True:
        from_ = int(len(paths) / 100 * start)
        to_ = int(len(paths) / 100 * end)
        for i in range(from_, int(to_)):
            f = paths[i]
            x = np.load(PathSpectogramFolder + f)
            x = np.array([x])
            x = x.swapaxes(0, 1)
            yield (x)


class EarlyStoppingByLossVal(keras.callbacks.Callback):
    def __init__(self, monitor='val_loss', value=0.00001, verbose=0, lower=True):
        super(keras.callbacks.Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose
        self.lower = lower

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if self.lower:
            if current < self.value:
                if self.verbose > 0:
                    print("Epoch %05d: early stopping THR" % epoch)
                self.model.stop_training = True
        else:
            if current > self.value:
                if self.verbose > 0:
                    print("Epoch %05d: early stopping THR" % epoch)
                self.model.stop_training = True


def main():
    print("START")
    if not os.path.exists(OutputPathModels):
        os.makedirs(OutputPathModels)
    loadParametersFromFile("PARAMETERS_CNN.txt")
    # callback=EarlyStopping(monitor='val_acc', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None)
    callback = EarlyStoppingByLossVal(monitor='val_acc', value=0.975, verbose=1, lower=False)
    print("Parameters loaded")

    for indexPat in range(0, len(patients)):
        print('Patient ' + patients[indexPat])
        if not os.path.exists(OutputPathModels + "ModelPat" + patients[indexPat] + "/"):
            os.makedirs(OutputPathModels + "ModelPat" + patients[indexPat] + "/")
        loadSpectogramData(indexPat)
        print('Spectograms data loaded')

        result = 'Patient ' + patients[indexPat] + '\n'
        result = 'Out Seizure, True Positive, False Positive, False negative, Second of Inter in Test, Sensitivity, FPR \n'
        for i in range(0, nSeizure):
            print('SEIZURE OUT: ' + str(i + 1))

            print('Training start')
            model = createModel()
            filesPath = getFilesPathWithoutSeizure(i, indexPat)

            model.fit_generator(generate_arrays_for_training(indexPat, filesPath, end=75),
                                # end=75),#It take the first 75%
                                validation_data=generate_arrays_for_training(indexPat, filesPath, start=75),
                                # start=75), #It take the last 25%
                                # steps_per_epoch=10000, epochs=10)
                                steps_per_epoch=int((len(filesPath) - int(len(filesPath) / 100 * 25))),  # *25),
                                validation_steps=int((len(filesPath) - int(len(filesPath) / 100 * 75))),  # *75),
                                verbose=2,
                                epochs=300, max_queue_size=2, shuffle=True, callbacks=[
                    callback])  # 100 epochs è meglio #aggiungere criterio di stop in base accuratezza
            print('Training end')

            print('Testing start')
            filesPath = interictalSpectograms[i]
            interPrediction = model.predict_generator(generate_arrays_for_predict(indexPat, filesPath),
                                                      max_queue_size=4, steps=len(filesPath))
            filesPath = preictalRealSpectograms[i]
            preictPrediction = model.predict_generator(generate_arrays_for_predict(indexPat, filesPath),
                                                       max_queue_size=4, steps=len(filesPath))
            print('Testing end')

            # Creates a HDF5 file 
            model.save(
                OutputPathModels + "ModelPat" + patients[indexPat] + "/" + 'ModelOutSeizure' + str(i + 1) + '.h5')
            print("Model saved")

            # to plot the model
            # plot_model(model, to_file="CNNModel", show_shapes=True, show_layer_names=True)

            if not os.path.exists(OutputPathModels + "OutputTest" + "/"):
                os.makedirs(OutputPathModels + "OutputTest" + "/")
            np.savetxt(OutputPathModels + "OutputTest" + "/" + "Int_" + patients[indexPat] + "_" + str(i + 1) + ".csv",
                       interPrediction, delimiter=",")
            np.savetxt(OutputPathModels + "OutputTest" + "/" + "Pre_" + patients[indexPat] + "_" + str(i + 1) + ".csv",
                       preictPrediction, delimiter=",")

            secondsInterictalInTest = len(
                interictalSpectograms[i]) * 50 * 30  # 50 spectograms for file, 30 seconds for each spectogram
            acc = 0  # accumulator
            fp = 0
            tp = 0
            fn = 0
            lastTenResult = list()

            for el in interPrediction:
                if (el[1] > 0.5):
                    acc = acc + 1
                    lastTenResult.append(1)
                else:
                    lastTenResult.append(0)
                if (len(lastTenResult) > 10):
                    acc = acc - lastTenResult.pop(0)
                if (acc >= 8):
                    fp = fp + 1
                    lastTenResult = list()
                    acc = 0

            lastTenResult = list()
            for el in preictPrediction:
                if (el[1] > 0.5):
                    acc = acc + 1
                    lastTenResult.append(1)
                else:
                    lastTenResult.append(0)
                if (len(lastTenResult) > 10):
                    acc = acc - lastTenResult.pop(0)
                if (acc >= 8):
                    tp = tp + 1
                else:
                    if (len(lastTenResult) == 10):
                        fn = fn + 1

            sensitivity = tp / (tp + fn)
            FPR = fp / (secondsInterictalInTest / (60 * 60))

            result = result + str(i + 1) + ',' + str(tp) + ',' + str(fp) + ',' + str(fn) + ',' + str(
                secondsInterictalInTest) + ','
            result = result + str(sensitivity) + ',' + str(FPR) + '\n'
            print('True Positive, False Positive, False negative, Second of Inter in Test, Sensitivity, FPR')
            print(str(tp) + ',' + str(fp) + ',' + str(fn) + ',' + str(secondsInterictalInTest) + ',' + str(
                sensitivity) + ',' + str(FPR))
        with open(OutputPath, "a+") as myfile:
            myfile.write(result)


if __name__ == '__main__':
    main()
# Out:
# START
# Parameters loaded
# Patient 09
# Spectograms data loaded
# SEIZURE OUT: 1
# Training start
# Epoch 1/300
#  - 41s - loss: 0.8542 - acc: 0.4910 - val_loss: 0.7025 - val_acc: 0.5043
# Epoch 2/300
#  - 33s - loss: 0.8323 - acc: 0.4979 - val_loss: 0.6954 - val_acc: 0.5448
# Epoch 3/300
#  - 41s - loss: 0.8136 - acc: 0.4957 - val_loss: 0.6911 - val_acc: 0.5588
# Epoch 4/300
#  - 52s - loss: 0.8225 - acc: 0.4893 - val_loss: 0.6878 - val_acc: 0.5646
# Epoch 5/300
#  - 42s - loss: 0.8063 - acc: 0.4927 - val_loss: 0.6839 - val_acc: 0.5727
# Epoch 6/300
#  - 50s - loss: 0.8028 - acc: 0.5106 - val_loss: 0.6814 - val_acc: 0.5930
# Epoch 7/300
#  - 40s - loss: 0.8125 - acc: 0.4880 - val_loss: 0.6815 - val_acc: 0.5835
# Epoch 8/300
#  - 45s - loss: 0.7931 - acc: 0.5087 - val_loss: 0.6763 - val_acc: 0.6047
# Epoch 9/300
#  - 36s - loss: 0.8023 - acc: 0.4945 - val_loss: 0.6786 - val_acc: 0.5979
# Epoch 10/300
#  - 45s - loss: 0.8023 - acc: 0.5076 - val_loss: 0.6731 - val_acc: 0.6267
# Epoch 11/300
#  - 42s - loss: 0.7807 - acc: 0.5124 - val_loss: 0.6705 - val_acc: 0.6403
# Epoch 12/300
#  - 43s - loss: 0.7842 - acc: 0.5110 - val_loss: 0.6679 - val_acc: 0.6452
# Epoch 13/300
#  - 48s - loss: 0.7821 - acc: 0.5141 - val_loss: 0.6614 - val_acc: 0.6880
# Epoch 14/300
#  - 41s - loss: 0.7832 - acc: 0.5097 - val_loss: 0.6660 - val_acc: 0.6425
# Epoch 15/300
#  - 48s - loss: 0.7723 - acc: 0.5253 - val_loss: 0.6607 - val_acc: 0.6628
# Epoch 16/300
#  - 48s - loss: 0.7709 - acc: 0.5112 - val_loss: 0.6571 - val_acc: 0.6907
# Epoch 17/300
#  - 40s - loss: 0.7768 - acc: 0.5182 - val_loss: 0.6492 - val_acc: 0.7186
# Epoch 18/300
#  - 48s - loss: 0.7722 - acc: 0.5094 - val_loss: 0.6479 - val_acc: 0.7033
# Epoch 19/300
#  - 43s - loss: 0.7639 - acc: 0.5234 - val_loss: 0.6423 - val_acc: 0.7240
# Epoch 20/300
#  - 36s - loss: 0.7567 - acc: 0.5361 - val_loss: 0.6338 - val_acc: 0.7510
# Epoch 21/300
#  - 48s - loss: 0.7671 - acc: 0.5217 - val_loss: 0.6288 - val_acc: 0.7533
# Epoch 22/300
#  - 44s - loss: 0.7525 - acc: 0.5385 - val_loss: 0.6211 - val_acc: 0.7609
# Epoch 23/300
#  - 44s - loss: 0.7505 - acc: 0.5405 - val_loss: 0.6074 - val_acc: 0.7735
# Epoch 24/300
#  - 42s - loss: 0.7526 - acc: 0.5368 - val_loss: 0.6029 - val_acc: 0.7758
# Epoch 25/300
#  - 45s - loss: 0.7353 - acc: 0.5583 - val_loss: 0.5942 - val_acc: 0.7704
# Epoch 26/300
#  - 39s - loss: 0.7357 - acc: 0.5456 - val_loss: 0.5832 - val_acc: 0.7839
# Epoch 27/300
#  - 47s - loss: 0.7305 - acc: 0.5604 - val_loss: 0.5761 - val_acc: 0.7870
# Epoch 28/300
#  - 39s - loss: 0.7267 - acc: 0.5587 - val_loss: 0.5684 - val_acc: 0.7866
# Epoch 29/300
#  - 48s - loss: 0.7229 - acc: 0.5677 - val_loss: 0.5616 - val_acc: 0.7843
# Epoch 30/300
#  - 38s - loss: 0.7099 - acc: 0.5845 - val_loss: 0.5504 - val_acc: 0.7857
# Epoch 31/300
#  - 48s - loss: 0.7193 - acc: 0.5784 - val_loss: 0.5505 - val_acc: 0.7834
# Epoch 32/300
#  - 41s - loss: 0.7101 - acc: 0.5728 - val_loss: 0.5400 - val_acc: 0.7852
# Epoch 33/300
#  - 48s - loss: 0.7018 - acc: 0.5805 - val_loss: 0.5385 - val_acc: 0.7740
# Epoch 34/300
#  - 45s - loss: 0.7081 - acc: 0.5895 - val_loss: 0.5252 - val_acc: 0.7902
# Epoch 35/300
#  - 44s - loss: 0.6928 - acc: 0.5946 - val_loss: 0.5214 - val_acc: 0.7830
# Epoch 36/300
#  - 44s - loss: 0.6907 - acc: 0.5913 - val_loss: 0.5172 - val_acc: 0.7848
# Epoch 37/300
#  - 46s - loss: 0.6948 - acc: 0.5907 - val_loss: 0.5113 - val_acc: 0.7897
# Epoch 38/300
#  - 44s - loss: 0.6826 - acc: 0.6000 - val_loss: 0.5075 - val_acc: 0.7956
# Epoch 39/300
#  - 48s - loss: 0.6750 - acc: 0.6175 - val_loss: 0.4979 - val_acc: 0.8019
# Epoch 40/300
#  - 44s - loss: 0.6831 - acc: 0.6139 - val_loss: 0.4930 - val_acc: 0.7983
# Epoch 41/300
#  - 53s - loss: 0.6768 - acc: 0.6147 - val_loss: 0.4912 - val_acc: 0.7983
# Epoch 42/300
#  - 41s - loss: 0.6595 - acc: 0.6246 - val_loss: 0.4892 - val_acc: 0.7974
# Epoch 43/300
#  - 45s - loss: 0.6665 - acc: 0.6253 - val_loss: 0.4853 - val_acc: 0.7983
# Epoch 44/300
#  - 37s - loss: 0.6711 - acc: 0.6139 - val_loss: 0.4919 - val_acc: 0.7821
# Epoch 45/300
#  - 48s - loss: 0.6647 - acc: 0.6237 - val_loss: 0.4925 - val_acc: 0.7708
# Epoch 46/300
#  - 37s - loss: 0.6600 - acc: 0.6234 - val_loss: 0.4832 - val_acc: 0.7780
# Epoch 47/300
#  - 45s - loss: 0.6533 - acc: 0.6301 - val_loss: 0.4902 - val_acc: 0.7690
# Epoch 48/300
#  - 44s - loss: 0.6553 - acc: 0.6308 - val_loss: 0.4935 - val_acc: 0.7573
# Epoch 49/300
#  - 39s - loss: 0.6487 - acc: 0.6366 - val_loss: 0.4995 - val_acc: 0.7474
# Epoch 50/300
#  - 54s - loss: 0.6499 - acc: 0.6404 - val_loss: 0.4977 - val_acc: 0.7470
# Epoch 51/300
#  - 39s - loss: 0.6401 - acc: 0.6392 - val_loss: 0.5055 - val_acc: 0.7330
# Epoch 52/300
#  - 47s - loss: 0.6436 - acc: 0.6404 - val_loss: 0.4844 - val_acc: 0.7582
# Epoch 53/300
#  - 41s - loss: 0.6307 - acc: 0.6540 - val_loss: 0.4805 - val_acc: 0.7636
# Epoch 54/300
#  - 44s - loss: 0.6309 - acc: 0.6535 - val_loss: 0.4730 - val_acc: 0.7726
# Epoch 55/300
#  - 44s - loss: 0.6326 - acc: 0.6535 - val_loss: 0.4727 - val_acc: 0.7839
# Epoch 56/300
#  - 42s - loss: 0.6252 - acc: 0.6526 - val_loss: 0.4620 - val_acc: 0.8086
# Epoch 57/300
#  - 47s - loss: 0.6236 - acc: 0.6499 - val_loss: 0.4554 - val_acc: 0.8149
# Epoch 58/300
#  - 44s - loss: 0.6267 - acc: 0.6518 - val_loss: 0.4583 - val_acc: 0.8091
# Epoch 59/300
#  - 47s - loss: 0.6117 - acc: 0.6626 - val_loss: 0.4593 - val_acc: 0.7965
# Epoch 60/300
#  - 45s - loss: 0.6206 - acc: 0.6580 - val_loss: 0.4672 - val_acc: 0.7879
# Epoch 61/300
#  - 49s - loss: 0.6188 - acc: 0.6607 - val_loss: 0.4749 - val_acc: 0.7753
# Epoch 62/300
#  - 43s - loss: 0.6090 - acc: 0.6644 - val_loss: 0.4702 - val_acc: 0.7735
# Epoch 63/300
#  - 45s - loss: 0.6044 - acc: 0.6707 - val_loss: 0.4859 - val_acc: 0.7546
# Epoch 64/300
#  - 39s - loss: 0.5975 - acc: 0.6715 - val_loss: 0.4802 - val_acc: 0.7614
# Epoch 65/300
#  - 46s - loss: 0.5982 - acc: 0.6777 - val_loss: 0.4852 - val_acc: 0.7564
# Epoch 66/300
#  - 37s - loss: 0.5932 - acc: 0.6782 - val_loss: 0.4749 - val_acc: 0.7591
# Epoch 67/300
#  - 38s - loss: 0.5947 - acc: 0.6793 - val_loss: 0.4890 - val_acc: 0.7438
# Epoch 68/300
#  - 45s - loss: 0.5919 - acc: 0.6816 - val_loss: 0.4740 - val_acc: 0.7641
# Epoch 69/300
#  - 46s - loss: 0.5902 - acc: 0.6830 - val_loss: 0.4763 - val_acc: 0.7618
# Epoch 70/300
#  - 42s - loss: 0.5944 - acc: 0.6807 - val_loss: 0.4890 - val_acc: 0.7497
# Epoch 71/300
#  - 46s - loss: 0.5828 - acc: 0.6845 - val_loss: 0.4595 - val_acc: 0.7861
# Epoch 72/300
#  - 38s - loss: 0.5874 - acc: 0.6835 - val_loss: 0.4493 - val_acc: 0.7929
# Epoch 73/300
#  - 45s - loss: 0.5760 - acc: 0.6928 - val_loss: 0.4623 - val_acc: 0.7731
# Epoch 74/300
#  - 41s - loss: 0.5890 - acc: 0.6863 - val_loss: 0.4431 - val_acc: 0.8032
# Epoch 75/300
#  - 49s - loss: 0.5786 - acc: 0.6836 - val_loss: 0.4431 - val_acc: 0.8010
# Epoch 76/300
#  - 45s - loss: 0.5695 - acc: 0.7035 - val_loss: 0.4499 - val_acc: 0.7987
# Epoch 77/300
#  - 47s - loss: 0.5733 - acc: 0.6924 - val_loss: 0.4474 - val_acc: 0.7933
# Epoch 78/300
#  - 41s - loss: 0.5722 - acc: 0.6961 - val_loss: 0.4632 - val_acc: 0.7704
# Epoch 79/300
#  - 45s - loss: 0.5730 - acc: 0.6991 - val_loss: 0.4518 - val_acc: 0.7857
# Epoch 80/300
#  - 44s - loss: 0.5701 - acc: 0.6985 - val_loss: 0.4465 - val_acc: 0.8023
# Epoch 81/300
#  - 40s - loss: 0.5605 - acc: 0.7012 - val_loss: 0.4453 - val_acc: 0.8172
# Epoch 82/300
#  - 42s - loss: 0.5599 - acc: 0.7053 - val_loss: 0.4413 - val_acc: 0.8149
# Epoch 83/300

# %%
# !zip -r /content/file.zip /content/project

# %%
from google.colab import files
files.download("/content/file.zip")
# Out:
# ----------------------------------------
# Exception happened during processing of request from ('::ffff:127.0.0.1', 36150, 0, 0)
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/socketserver.py", line 317, in _handle_request_noblock
#     self.process_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 348, in process_request
#     self.finish_request(request, client_address)
#   File "/usr/lib/python3.6/socketserver.py", line 361, in finish_request
#     self.RequestHandlerClass(request, client_address, self)
#   File "/usr/lib/python3.6/socketserver.py", line 721, in __init__
#     self.handle()
#   File "/usr/lib/python3.6/http/server.py", line 418, in handle
#     self.handle_one_request()
#   File "/usr/lib/python3.6/http/server.py", line 406, in handle_one_request
#     method()
#   File "/usr/lib/python3.6/http/server.py", line 639, in do_GET
#     self.copyfile(f, self.wfile)
#   File "/usr/lib/python3.6/http/server.py", line 800, in copyfile
#     shutil.copyfileobj(source, outputfile)
#   File "/usr/lib/python3.6/shutil.py", line 82, in copyfileobj
#     fdst.write(buf)
#   File "/usr/lib/python3.6/socketserver.py", line 800, in write
#     self._sock.sendall(b)
# ConnectionResetError: [Errno 104] Connection reset by peer
# ----------------------------------------

# %%
  from keras.models import load_model as model

modeld = model("/content/project/dataset/ModelPat01/ModelOutSeizure1.h5")

# %%
import os
# os.environ["CUDA_DEVICE_ORDER"] = "PCI_BUS_ID"   # see issue #152
# os.environ["CUDA_VISIBLE_DEVICES"] = ""
# FINE codice per allenare la rete sulla cpu

import keras
import numpy as np
from keras.models import load_model as model
from keras.models import Sequential
from keras.layers import Dense, Conv3D, Dropout, Flatten, BatchNormalization
from keras.callbacks import EarlyStopping
from random import shuffle
import math

# to plot the model
# from keras.utils.vis_utils import plot_model
# from keras.models import load_model
# Returns a compiled model identical to the saved one
# model = load_model('my_model.h5')

PathSpectogramFolder = './project/dataset/spectograms'
OutputPath = './project/dataset/results.txt'
OutputPathModels = './project/dataset/'
interictalSpectograms = []
preictalSpectograms = []
preictalRealSpectograms = []
#patients = ["01", "02", "03", "05", "09", "10", "13", "14", "18", "19", "20", "21", "23"]
patients = ["02"]
nSeizure = 0


def loadParametersFromFile(filePath):
    global PathSpectogramFolder
    global OutputPath
    global OutputPathModels
    if (os.path.isfile(filePath)):
        with open(filePath, "r") as f:
            line = f.readline()
            if (line.split(":")[0] == "PathSpectogramFolder"):
                PathSpectogramFolder = line.split(":")[1].strip()
            line = f.readline()
            if (line.split(":")[0] == "OutputPath"):
                OutputPath = line.split(":")[1].strip()
            line = f.readline()
            if (line.split(":")[0] == "OutputPathModels"):
                OutputPathModels = line.split(":")[1].strip()


def loadSpectogramData(indexPat):
    global interictalSpectograms
    global preictalSpectograms
    global preictalRealSpectograms
    global nSeizure
    nFileForSeizure = 0

    interictalSpectograms = []
    preictalSpectograms = []
    preictalRealSpectograms = []

    f = open(PathSpectogramFolder + '/paz' + patients[indexPat] + '/legendAllData.txt', 'r')
    line = f.readline()
    while (not "SEIZURE" in line):
        line = f.readline()
    nSeizure = int(line.split(":")[1].strip())
    line = f.readline()
    line = f.readline()  # legge il numero di spectogrammi. non lo salvo dato che non mi serve
    nSpectograms = int(line.strip())
    nFileForSeizure = math.ceil(math.ceil(nSpectograms / 50) / nSeizure)
    line = f.readline()  # leggo il percorso del primo file

    # Lettura path files Interictal
    cont = -1
    indFilePathRead = 0
    while ("npy" in line and indFilePathRead < nSeizure * nFileForSeizure):
        if (indFilePathRead % nFileForSeizure == 0):
            interictalSpectograms.append([])
            cont = cont + 1
            interictalSpectograms[cont].append(line.split(' ')[2].rstrip())  # .rstrip() remove \n
            indFilePathRead = indFilePathRead + 1
        else:
            if (len(line.split(' ')) >= 3):
                interictalSpectograms[cont].append(line.split(' ')[2].rstrip())
            indFilePathRead = indFilePathRead + 1

        line = f.readline()
    line = f.readline()  # leggo PREICTAL
    line = f.readline()  # leggo n° spectogram
    line = f.readline()  # leggo n°seizure(SEIZURE X)

    cont = -1
    indFilePathRead = 0
    # while(line and indFilePathRead<nSeizure*nFileForSeizure):
    while (line.strip() != ""):
        if ("SEIZURE" in line):
            line = f.readline()  # ho letto n°seizure(SEIZURE X) perciò scorro in avanti
            if (len(line.split(' ')) >= 3):
                preictalSpectograms.append([])
                cont = cont + 1
                preictalSpectograms[cont].append(line.split(' ')[2].rstrip())
                indFilePathRead = indFilePathRead + 1
        else:
            if (len(line.split(' ')) >= 3):
                preictalSpectograms[cont].append(line.split(' ')[2].rstrip())
            indFilePathRead = indFilePathRead + 1

        line = f.readline()

    line = f.readline()  # leggo REAL_PREICTAL
    line = f.readline()  # leggo n° spectogram
    line = f.readline()  # leggo n°seizure(SEIZURE X)

    cont = -1
    while (line):
        if ("SEIZURE" in line):
            line = f.readline()
            preictalRealSpectograms.append([])
            cont = cont + 1
            preictalRealSpectograms[cont].append(line.split(' ')[2].rstrip())
        else:
            preictalRealSpectograms[cont].append(line.split(' ')[2].rstrip())

        line = f.readline()
    f.close()



def getFilesPathWithoutSeizure(indexSeizure, indexPat):
    filesPath = []
    for i in range(0, nSeizure):
        if (i != indexSeizure):
            filesPath.extend(interictalSpectograms[i])
            filesPath.extend(preictalSpectograms[i])
    shuffle(filesPath)
    return filesPath


def generate_arrays_for_training(indexPat, paths, start=0, end=100):
    while True:
        from_ = int(len(paths) / 100 * start)
        to_ = int(len(paths) / 100 * end)
        for i in range(from_, int(to_)):
            f = paths[i]
            x = np.load(PathSpectogramFolder + f)
            x = np.array([x])
            x = x.swapaxes(0, 1)
            if ('P' in f):
                y = np.repeat([[0, 1]], x.shape[0], axis=0)
            else:
                y = np.repeat([[1, 0]], x.shape[0], axis=0)
            yield (x, y)


def generate_arrays_for_predict(indexPat, paths, start=0, end=100):
    while True:
        from_ = int(len(paths) / 100 * start)
        to_ = int(len(paths) / 100 * end)
        for i in range(from_, int(to_)):
            f = paths[i]
            x = np.load(PathSpectogramFolder + f)
            x = np.array([x])
            x = x.swapaxes(0, 1)
            yield (x)


class EarlyStoppingByLossVal(keras.callbacks.Callback):
    def __init__(self, monitor='val_loss', value=0.00001, verbose=0, lower=True):
        super(keras.callbacks.Callback, self).__init__()
        self.monitor = monitor
        self.value = value
        self.verbose = verbose
        self.lower = lower

    def on_epoch_end(self, epoch, logs={}):
        current = logs.get(self.monitor)
        if self.lower:
            if current < self.value:
                if self.verbose > 0:
                    print("Epoch %05d: early stopping THR" % epoch)
                self.model.stop_training = True
        else:
            if current > self.value:
                if self.verbose > 0:
                    print("Epoch %05d: early stopping THR" % epoch)
                self.model.stop_training = True


def main():
    print("START")
    if not os.path.exists(OutputPathModels):
        os.makedirs(OutputPathModels)
    loadParametersFromFile("PARAMETERS_CNN.txt")
    # callback=EarlyStopping(monitor='val_acc', min_delta=0, patience=0, verbose=0, mode='auto', baseline=None)
    callback = EarlyStoppingByLossVal(monitor='val_acc', value=0.975, verbose=1, lower=False)
    print("Parameters loaded")

    for indexPat in range(0, len(patients)):
        print('Patient ' + patients[indexPat])
        if not os.path.exists(OutputPathModels + "ModelPat" + patients[indexPat] + "/"):
            os.makedirs(OutputPathModels + "ModelPat" + patients[indexPat] + "/")
        loadSpectogramData(indexPat)
        print('Spectograms data loaded')

        result = 'Patient ' + patients[indexPat] + '\n'
        result = 'Out Seizure, True Positive, False Positive, False negative, Second of Inter in Test, Sensitivity, FPR \n'
        for i in range(0, nSeizure):
            print('SEIZURE OUT: ' + str(i + 1))
          
            
            modeld=model(OutputPathModels + "ModelPat" + "01"+ "/" + 'ModelOutSeizure' + str(i + 1) + '.h5')
            filesPath = interictalSpectograms[i]
            interPrediction = modeld.predict_generator(generate_arrays_for_predict(indexPat, filesPath),
                                                      max_queue_size=4, steps=len(filesPath))
            filesPath = preictalRealSpectograms[i]
            preictPrediction = modeld.predict_generator(generate_arrays_for_predict(indexPat, filesPath),
                                                       max_queue_size=4, steps=len(filesPath))
            print("prediction:",preictPrediction)
           
            
            secondsInterictalInTest = len(
                interictalSpectograms[i]) * 50 * 30  # 50 spectograms for file, 30 seconds for each spectogram
            acc = 0  # accumulator
            fp = 0
            tp = 0
            fn = 0
            lastTenResult = list()

            for el in interPrediction:
                if (el[1] > 0.5):
                    acc = acc + 1
                    lastTenResult.append(1)
                else:
                    lastTenResult.append(0)
                if (len(lastTenResult) > 10):
                    acc = acc - lastTenResult.pop(0)
                if (acc >= 8):
                    fp = fp + 1
                    lastTenResult = list()
                    acc = 0

            lastTenResult = list()
            for el in preictPrediction:
                if (el[1] > 0.5):
                    acc = acc + 1
                    lastTenResult.append(1)
                else:
                    lastTenResult.append(0)
                if (len(lastTenResult) > 10):
                    acc = acc - lastTenResult.pop(0)
                if (acc >= 8):
                    tp = tp + 1
                else:
                    if (len(lastTenResult) == 10):
                        fn = fn + 1

            sensitivity = tp / (tp + fn)
            FPR = fp / (secondsInterictalInTest / (60 * 60))

            result = result + str(i + 1) + ',' + str(tp) + ',' + str(fp) + ',' + str(fn) + ',' + str(
                secondsInterictalInTest) + ','
            result = result + str(sensitivity) + ',' + str(FPR) + '\n'
            print('True Positive, False Positive, False negative, Second of Inter in Test, Sensitivity, FPR')
            print(str(tp) + ',' + str(fp) + ',' + str(fn) + ',' + str(secondsInterictalInTest) + ',' + str(
                sensitivity) + ',' + str(FPR))
        with open(OutputPath, "a+") as myfile:
            myfile.write(result)
            print(result)

if __name__ == '__main__':
    main()

# %%
predict = modeld.predict(generate_arrays_for_predict(indexPat, filesPath))
predict
